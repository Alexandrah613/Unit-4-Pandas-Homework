# %% [markdown]
# Reading CSVs

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %%
aapl_historical = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_aapl_historical.csv')
algo_returns = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_algo_returns.csv')
cost_historical = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_cost_historical.csv')
goog_historical = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_goog_historical.csv')
sp500_historical = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_sp500_history.csv')
whale_returns = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_whale_returns.csv')

# %% [markdown]
# Read Whale Returns

# %%
whale_returns.head(10)
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
# 5  2015-03-09                   0.000582            0.004225
# 6  2015-03-10                  -0.010263           -0.005341
# 7  2015-03-11                   0.004012            0.005163
# 8  2015-03-12                   0.008265            0.010272
# 9  2015-03-13                  -0.002497           -0.001428
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098
# 5                     0.005843               -0.001652
# 6                    -0.012079               -0.009739
# 7                     0.003312               -0.001147
# 8                     0.013117                0.010801
# 9                    -0.003697               -0.008142

# %%
whale_returns.shape
# Out:
# (1060, 5)

# %%
whale_returns.count()
# Out:
# Date                           1060
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %% [markdown]
# Sorting Date from Ascending

# %%
whale_returns.sort_values("Date")
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                        NaN                 NaN
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# 3                        0.002355                0.006726
# 4                       -0.008481               -0.013098
# ...                           ...                     ...
# 1055                    -0.005153                0.004848
# 1056                     0.012355                0.010434
# 1057                     0.006251                0.005223
# 1058                    -0.000259               -0.003702
# 1059                    -0.007936               -0.007833
#
# [1060 rows x 5 columns]

# %% [markdown]
# Setting Index as Date

# %%
whale_returns = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_whale_returns.csv')
whale_returns.set_index(pd.to_datetime(whale_returns['Date'], infer_datetime_format=True), inplace=True)
whale_returns
# Out:
#                   Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02  2015-03-02                        NaN                 NaN
# 2015-03-03  2015-03-03                  -0.001266           -0.004981
# 2015-03-04  2015-03-04                   0.002230            0.003241
# 2015-03-05  2015-03-05                   0.004016            0.004076
# 2015-03-06  2015-03-06                  -0.007905           -0.003574
# ...                ...                        ...                 ...
# 2019-04-25  2019-04-25                  -0.000285           -0.001291
# 2019-04-26  2019-04-26                   0.008149            0.009162
# 2019-04-29  2019-04-29                   0.001254            0.002719
# 2019-04-30  2019-04-30                  -0.001295           -0.002211
# 2019-05-01  2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1060 rows x 5 columns]

# %% [markdown]
# Find Nulls

# %%
whale_returns.isnull()
# Out:
#              Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02  False                       True                True
# 2015-03-03  False                      False               False
# 2015-03-04  False                      False               False
# 2015-03-05  False                      False               False
# 2015-03-06  False                      False               False
# ...           ...                        ...                 ...
# 2019-04-25  False                      False               False
# 2019-04-26  False                      False               False
# 2019-04-29  False                      False               False
# 2019-04-30  False                      False               False
# 2019-05-01  False                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# 2015-03-04                        False                   False
# 2015-03-05                        False                   False
# 2015-03-06                        False                   False
# ...                                 ...                     ...
# 2019-04-25                        False                   False
# 2019-04-26                        False                   False
# 2019-04-29                        False                   False
# 2019-04-30                        False                   False
# 2019-05-01                        False                   False
#
# [1060 rows x 5 columns]

# %% [markdown]
# Count Nulls

# %%
whale_returns.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %% [markdown]
# Renaming Columns

# %%
columns = ["DATE", "SOROS FUND MANAGEMENT LLC", "PAULSON & CO INC", "TIGER GLOBAL MANAGEMENT LLC", "BERKSHIRE HATHAWAY INC"]
whale_returns.columns = columns
whale_returns.head()
# Out:
#                   DATE  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# Date
# 2015-03-02  2015-03-02                        NaN               NaN
# 2015-03-03  2015-03-03                  -0.001266         -0.004981
# 2015-03-04  2015-03-04                   0.002230          0.003241
# 2015-03-05  2015-03-05                   0.004016          0.004076
# 2015-03-06  2015-03-06                  -0.007905         -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %% [markdown]
# Renaming Nulls to Drop

# %%
whale_returns["PAULSON & CO INC"] = whale_returns["PAULSON & CO INC"].fillna("Unknown")
whale_returns
# Out:
#                   DATE  SOROS FUND MANAGEMENT LLC PAULSON & CO INC  \
# Date
# 2015-03-02  2015-03-02                        NaN          Unknown
# 2015-03-03  2015-03-03                  -0.001266      -0.00498052
# 2015-03-04  2015-03-04                   0.002230       0.00324128
# 2015-03-05  2015-03-05                   0.004016       0.00407605
# 2015-03-06  2015-03-06                  -0.007905      -0.00357403
# ...                ...                        ...              ...
# 2019-04-25  2019-04-25                  -0.000285      -0.00129083
# 2019-04-26  2019-04-26                   0.008149       0.00916168
# 2019-04-29  2019-04-29                   0.001254       0.00271917
# 2019-04-30  2019-04-30                  -0.001295      -0.00221145
# 2019-05-01  2019-05-01                  -0.005847      -0.00134119
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1060 rows x 5 columns]

# %% [markdown]
# Dropping Nulls

# %%
whale_returns = whale_returns.dropna()
whale_returns
# Out:
#                   DATE  SOROS FUND MANAGEMENT LLC PAULSON & CO INC  \
# Date
# 2015-03-03  2015-03-03                  -0.001266      -0.00498052
# 2015-03-04  2015-03-04                   0.002230       0.00324128
# 2015-03-05  2015-03-05                   0.004016       0.00407605
# 2015-03-06  2015-03-06                  -0.007905      -0.00357403
# 2015-03-09  2015-03-09                   0.000582       0.00422541
# ...                ...                        ...              ...
# 2019-04-25  2019-04-25                  -0.000285      -0.00129083
# 2019-04-26  2019-04-26                   0.008149       0.00916168
# 2019-04-29  2019-04-29                   0.001254       0.00271917
# 2019-04-30  2019-04-30                  -0.001295      -0.00221145
# 2019-05-01  2019-05-01                  -0.005847      -0.00134119
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 5 columns]

# %% [markdown]
# Dropping Extra Date Column

# %%
whale_returns = whale_returns.drop(columns=["DATE"])
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC PAULSON & CO INC  \
# Date
# 2015-03-03                  -0.001266      -0.00498052
# 2015-03-04                   0.002230       0.00324128
# 2015-03-05                   0.004016       0.00407605
# 2015-03-06                  -0.007905      -0.00357403
# 2015-03-09                   0.000582       0.00422541
# ...                               ...              ...
# 2019-04-25                  -0.000285      -0.00129083
# 2019-04-26                   0.008149       0.00916168
# 2019-04-29                   0.001254       0.00271917
# 2019-04-30                  -0.001295      -0.00221145
# 2019-05-01                  -0.005847      -0.00134119
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %% [markdown]
# Checking Nulls Again

# %%
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO INC               0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# Read Algo Returns

# %%
algo_returns.head(10)
# Out:
#          Date    Algo 1    Algo 2
# 0  2014-05-28  0.001745       NaN
# 1  2014-05-29  0.003978       NaN
# 2  2014-05-30  0.004464       NaN
# 3  2014-06-02  0.005692       NaN
# 4  2014-06-03  0.005292       NaN
# 5  2014-06-04 -0.001838       NaN
# 6  2014-06-05  0.004062  0.013285
# 7  2014-06-06  0.001857  0.008284
# 8  2014-06-09 -0.005012  0.005668
# 9  2014-06-10  0.004406 -0.000735

# %%
algo_returns.shape
# Out:
# (1241, 3)

# %%
algo_returns.count
# Out:
# <bound method DataFrame.count of             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]>

# %% [markdown]
# Sort Date from Ascending

# %%
algo_returns.sort_values("Date")
# Out:
#             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %% [markdown]
# Setting Index as Date

# %%
algo_returns = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_algo_returns.csv')
algo_returns.set_index(pd.to_datetime(algo_returns['Date'], infer_datetime_format=True), inplace=True)
algo_returns
# Out:
#                   Date    Algo 1    Algo 2
# Date
# 2014-05-28  2014-05-28  0.001745       NaN
# 2014-05-29  2014-05-29  0.003978       NaN
# 2014-05-30  2014-05-30  0.004464       NaN
# 2014-06-02  2014-06-02  0.005692       NaN
# 2014-06-03  2014-06-03  0.005292       NaN
# ...                ...       ...       ...
# 2019-04-25  2019-04-25  0.000682 -0.007247
# 2019-04-26  2019-04-26  0.002981  0.005256
# 2019-04-29  2019-04-29  0.005208  0.002829
# 2019-04-30  2019-04-30 -0.002944 -0.001570
# 2019-05-01  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %% [markdown]
# Dropping Extra Date Column

# %%
algo_returns.drop(columns=['Date'], inplace=True)
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %% [markdown]
# Checking Nulls

# %%
algo_returns.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %% [markdown]
# Counting Nulls

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %% [markdown]
# Preparing to Drop Nulls

# %%
algo_returns["Algo 2"] = algo_returns["Algo 2"].fillna("Unknown")
algo_returns
# Out:
#               Algo 1      Algo 2
# Date
# 2014-05-28  0.001745     Unknown
# 2014-05-29  0.003978     Unknown
# 2014-05-30  0.004464     Unknown
# 2014-06-02  0.005692     Unknown
# 2014-06-03  0.005292     Unknown
# ...              ...         ...
# 2019-04-25  0.000682 -0.00724746
# 2019-04-26  0.002981  0.00525564
# 2019-04-29  0.005208  0.00282934
# 2019-04-30 -0.002944 -0.00156965
# 2019-05-01  0.000094 -0.00735803
#
# [1241 rows x 2 columns]

# %% [markdown]
# Drop Nulls

# %%
algo_returns = algo_returns.dropna()
algo_returns
# Out:
#               Algo 1      Algo 2
# Date
# 2014-05-28  0.001745     Unknown
# 2014-05-29  0.003978     Unknown
# 2014-05-30  0.004464     Unknown
# 2014-06-02  0.005692     Unknown
# 2014-06-03  0.005292     Unknown
# ...              ...         ...
# 2019-04-25  0.000682 -0.00724746
# 2019-04-26  0.002981  0.00525564
# 2019-04-29  0.005208  0.00282934
# 2019-04-30 -0.002944 -0.00156965
# 2019-05-01  0.000094 -0.00735803
#
# [1241 rows x 2 columns]

# %% [markdown]
# Checking Nulls Again

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# Reading SP Historical Data

# %%
sp500_historical.head(10)
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06
# 5  15-Apr-19  $2905.58
# 6  12-Apr-19  $2907.41
# 7  11-Apr-19  $2888.32
# 8  10-Apr-19  $2888.21
# 9   9-Apr-19  $2878.20

# %% [markdown]
# Setting Date as Ascending

# %%
sp500_historical.sort_values("Date")
# Out:
#           Date     Close
# 1526  1-Apr-13  $1562.17
# 1273  1-Apr-14  $1885.52
# 1021  1-Apr-15  $2059.69
# 769   1-Apr-16  $2072.78
# 15    1-Apr-19  $2867.19
# ...        ...       ...
# 133   9-Oct-18  $2880.34
# 1414  9-Sep-13  $1671.71
# 1162  9-Sep-14  $1988.44
# 910   9-Sep-15  $1942.04
# 657   9-Sep-16  $2127.81
#
# [1649 rows x 2 columns]

# %% [markdown]
# Making Sure Date is Index

# %%
sp500_historical = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_sp500_history.csv')
sp500_historical.set_index(pd.to_datetime(sp500_historical['Date'], infer_datetime_format=True), inplace=True)
sp500_historical
# Out:
#                  Date     Close
# Date
# 2019-04-23  23-Apr-19  $2933.68
# 2019-04-22  22-Apr-19  $2907.97
# 2019-04-18  18-Apr-19  $2905.03
# 2019-04-17  17-Apr-19  $2900.45
# 2019-04-16  16-Apr-19  $2907.06
# ...               ...       ...
# 2012-10-05   5-Oct-12  $1460.93
# 2012-10-04   4-Oct-12  $1461.40
# 2012-10-03   3-Oct-12  $1450.99
# 2012-10-02   2-Oct-12  $1445.75
# 2012-10-01   1-Oct-12  $1444.49
#
# [1649 rows x 2 columns]

# %% [markdown]
# Dropping Extra Date Column

# %%
sp500_historical.drop(columns=['Date'], inplace=True)
sp500_historical
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06
# ...              ...
# 2012-10-05  $1460.93
# 2012-10-04  $1461.40
# 2012-10-03  $1450.99
# 2012-10-02  $1445.75
# 2012-10-01  $1444.49
#
# [1649 rows x 1 columns]

# %% [markdown]
# Checking Data Types

# %%
sp500_historical.dtypes
# Out:
# Close    object
# dtype: object

# %% [markdown]
# Checking for Nulls

# %%
sp500_historical.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %% [markdown]
# Dropping '$'

# %%
sp500_historical["Close"] = sp500_historical["Close"].str.replace("$", "")
sp500_historical
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06
# ...             ...
# 2012-10-05  1460.93
# 2012-10-04  1461.40
# 2012-10-03  1450.99
# 2012-10-02  1445.75
# 2012-10-01  1444.49
#
# [1649 rows x 1 columns]

# %% [markdown]
# Setting Close Column as Float

# %%
sp500_historical["Close"] = sp500_historical["Close"].astype("float")

# %% [markdown]
# Here is where I get confused, why is it a float datatype object? It gets declared as integer in the next line. Why?

# %%
sp500_historical.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_historical.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %% [markdown]
# Calculating the Returns using pct_change

# %%
SP_daily_returns = sp500_historical.pct_change()
SP_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %% [markdown]
# Sort Date as Ascending

# %%
SP_daily_returns.sort_values("Date")
# Out:
#                Close
# Date
# 2012-10-01 -0.000872
# 2012-10-02 -0.003611
# 2012-10-03 -0.007123
# 2012-10-04  0.000322
# 2012-10-05  0.003469
# ...              ...
# 2019-04-16  0.002279
# 2019-04-17 -0.001577
# 2019-04-18 -0.001011
# 2019-04-22 -0.008764
# 2019-04-23       NaN
#
# [1649 rows x 1 columns]

# %% [markdown]
# Checking Nulls

# %%
SP_daily_returns.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %% [markdown]
# Preparing Nulls

# %%
SP_daily_returns["Close"] = SP_daily_returns["Close"].fillna("Unknown")
SP_daily_returns
# Out:
#                   Close
# Date
# 2019-04-23      Unknown
# 2019-04-22  -0.00876374
# 2019-04-18  -0.00101101
# 2019-04-17  -0.00157658
# 2019-04-16   0.00227896
# ...                 ...
# 2012-10-05   0.00346869
# 2012-10-04  0.000321713
# 2012-10-03  -0.00712331
# 2012-10-02  -0.00361133
# 2012-10-01  -0.00087152
#
# [1649 rows x 1 columns]

# %% [markdown]
# Dropping Nulls

# %%
SP_daily_returns.loc["2019-04-23", "Close"] = 0
SP_daily_returns
# Out:
#                   Close
# Date
# 2019-04-23            0
# 2019-04-22  -0.00876374
# 2019-04-18  -0.00101101
# 2019-04-17  -0.00157658
# 2019-04-16   0.00227896
# ...                 ...
# 2012-10-05   0.00346869
# 2012-10-04  0.000321713
# 2012-10-03  -0.00712331
# 2012-10-02  -0.00361133
# 2012-10-01  -0.00087152
#
# [1649 rows x 1 columns]

# %% [markdown]
# Checking Nulls Again

# %%
SP_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %% [markdown]
# Renaming Columns

# %%
SP_daily_returns = SP_daily_returns.rename(columns={
    "Close": "SP500 Returns"
})
SP_daily_returns
# Out:
#            SP500 Returns
# Date
# 2019-04-23             0
# 2019-04-22   -0.00876374
# 2019-04-18   -0.00101101
# 2019-04-17   -0.00157658
# 2019-04-16    0.00227896
# ...                  ...
# 2012-10-05    0.00346869
# 2012-10-04   0.000321713
# 2012-10-03   -0.00712331
# 2012-10-02   -0.00361133
# 2012-10-01   -0.00087152
#
# [1649 rows x 1 columns]

# %% [markdown]
# Sorting Date by Ascending Again

# %%
SP_daily_returns.sort_values("Date")
# Out:
#            SP500 Returns
# Date
# 2012-10-01   -0.00087152
# 2012-10-02   -0.00361133
# 2012-10-03   -0.00712331
# 2012-10-04   0.000321713
# 2012-10-05    0.00346869
# ...                  ...
# 2019-04-16    0.00227896
# 2019-04-17   -0.00157658
# 2019-04-18   -0.00101101
# 2019-04-22   -0.00876374
# 2019-04-23             0
#
# [1649 rows x 1 columns]

# %%
SP_daily_returns.isnull().sum()
# Out:
# SP500 Returns    0
# dtype: int64

# %%
SP_returns_data = SP_daily_returns
SP_returns_data
# Out:
#            SP500 Returns
# Date
# 2019-04-23             0
# 2019-04-22   -0.00876374
# 2019-04-18   -0.00101101
# 2019-04-17   -0.00157658
# 2019-04-16    0.00227896
# ...                  ...
# 2012-10-05    0.00346869
# 2012-10-04   0.000321713
# 2012-10-03   -0.00712331
# 2012-10-02   -0.00361133
# 2012-10-01   -0.00087152
#
# [1649 rows x 1 columns]

# %%
SP_returns_data.isnull
# Out:
# <bound method DataFrame.isnull of            SP500 Returns
# Date
# 2019-04-23             0
# 2019-04-22   -0.00876374
# 2019-04-18   -0.00101101
# 2019-04-17   -0.00157658
# 2019-04-16    0.00227896
# ...                  ...
# 2012-10-05    0.00346869
# 2012-10-04   0.000321713
# 2012-10-03   -0.00712331
# 2012-10-02   -0.00361133
# 2012-10-01   -0.00087152
#
# [1649 rows x 1 columns]>

# %% [markdown]
# Checking for Nulls Again

# %%
SP_returns_data.isnull().sum()
# Out:
# SP500 Returns    0
# dtype: int64

# %% [markdown]
# Asking for datatypes and I'm still confused at the different dtype

# %%
SP_returns_data.dtypes
# Out:
# SP500 Returns    object
# dtype: object

# %% [markdown]
# Preparing to Concatenate

# %%
whale_returns_data = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_whale_returns.csv', index_col = 'Date')
algo_returns_data = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_algo_returns.csv', index_col = 'Date')
SP_returns_data = pd.read_csv('Homework_04-Pandas_Instructions_Starter_Code_Resources_sp500_history.csv', index_col = 'Date')

# %% [markdown]
# Concatenating DF's

# %%
joined_closing_data = pd.concat([whale_returns_data, algo_returns_data, SP_daily_returns], axis="columns", join="outer")
joined_closing_data
# Out:
#                      SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2012-10-01 00:00:00                        NaN                 NaN
# 2012-10-02 00:00:00                        NaN                 NaN
# 2012-10-03 00:00:00                        NaN                 NaN
# 2012-10-04 00:00:00                        NaN                 NaN
# 2012-10-05 00:00:00                        NaN                 NaN
# ...                                        ...                 ...
# 2019-04-25                           -0.000285           -0.001291
# 2019-04-26                            0.008149            0.009162
# 2019-04-29                            0.001254            0.002719
# 2019-04-30                           -0.001295           -0.002211
# 2019-05-01                           -0.005847           -0.001341
#
#                      TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  \
# Date
# 2012-10-01 00:00:00                          NaN                     NaN
# 2012-10-02 00:00:00                          NaN                     NaN
# 2012-10-03 00:00:00                          NaN                     NaN
# 2012-10-04 00:00:00                          NaN                     NaN
# 2012-10-05 00:00:00                          NaN                     NaN
# ...                                          ...                     ...
# 2019-04-25                             -0.005153                0.004848
# 2019-04-26                              0.012355                0.010434
# 2019-04-29                              0.006251                0.005223
# 2019-04-30                             -0.000259               -0.003702
# 2019-05-01                             -0.007936               -0.007833
#
#                        Algo 1    Algo 2 SP500 Returns
# Date
# 2012-10-01 00:00:00       NaN       NaN   -0.00087152
# 2012-10-02 00:00:00       NaN       NaN   -0.00361133
# 2012-10-03 00:00:00       NaN       NaN   -0.00712331
# 2012-10-04 00:00:00       NaN       NaN   0.000321713
# 2012-10-05 00:00:00       NaN       NaN    0.00346869
# ...                       ...       ...           ...
# 2019-04-25           0.000682 -0.007247           NaN
# 2019-04-26           0.002981  0.005256           NaN
# 2019-04-29           0.005208  0.002829           NaN
# 2019-04-30          -0.002944 -0.001570           NaN
# 2019-05-01           0.000094 -0.007358           NaN
#
# [2900 rows x 7 columns]

# %% [markdown]
# Plot Whale Daily Returns

# %%
whale_returns_data.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Whale Cumulative Returns

# %%
whale_cumulative_returns = (1 + whale_returns_data).cumprod()
whale_cumulative_returns.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
# 2015-03-10                   0.987379            0.997595
# 2015-03-11                   0.991340            1.002746
# 2015-03-12                   0.999533            1.013045
# 2015-03-13                   0.997037            1.011598
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                     0.999504                0.993431
# 2015-03-04                     0.996972                0.997617
# 2015-03-05                     0.999319                1.004327
# 2015-03-06                     0.990844                0.991172
# 2015-03-09                     0.996633                0.989534
# 2015-03-10                     0.984595                0.979897
# 2015-03-11                     0.987855                0.978774
# 2015-03-12                     1.000813                0.989346
# 2015-03-13                     0.997113                0.981290

# %% [markdown]
# Plotting Whale Cumulative Returns

# %%
whale_cumulative_returns.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Daily Standard Deviation

# %%
whale_std = whale_returns_data.std()
whale_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %% [markdown]
# Annual Standard Deviation

# %%
whale_annualized_std = whale_std * np.sqrt(252)
whale_annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124487
# PAULSON & CO.INC.              0.110754
# TIGER GLOBAL MANAGEMENT LLC    0.171830
# BERKSHIRE HATHAWAY INC         0.203682
# dtype: float64

# %% [markdown]
# Whale Rolling Statistics

# %%
whale_returns_data.rolling(window=21).mean().tail(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-17                   0.001305       -2.516183e-04
# 2019-04-18                   0.001597        1.953116e-05
# 2019-04-22                   0.000754       -5.556595e-04
# 2019-04-23                   0.001937        2.625556e-04
# 2019-04-24                   0.002204        3.305858e-04
# 2019-04-25                   0.001982        5.009154e-07
# 2019-04-26                   0.002560        7.854086e-04
# 2019-04-29                   0.002466        1.246472e-03
# 2019-04-30                   0.002339        9.968624e-04
# 2019-05-01                   0.001632        4.533365e-04
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2019-04-17                     0.000996                0.001581
# 2019-04-18                     0.001376                0.001691
# 2019-04-22                     0.000303                0.001004
# 2019-04-23                     0.001408                0.002981
# 2019-04-24                     0.001172                0.002166
# 2019-04-25                     0.000489                0.002140
# 2019-04-26                     0.001281                0.002925
# 2019-04-29                     0.001296                0.002890
# 2019-04-30                     0.001344                0.002105
# 2019-05-01                     0.000777                0.001104

# %% [markdown]
# Whale Rolling Stat Plot

# %%
whale_returns_data.rolling(window=21).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Plot Algo Daily Returns

# %%
algo_returns_data.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Algo Cumulative Returns

# %%
algo_cumulative_returns = (1 + algo_returns_data).cumprod()
algo_cumulative_returns.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  1.001745       NaN
# 2014-05-29  1.005730       NaN
# 2014-05-30  1.010219       NaN
# 2014-06-02  1.015970       NaN
# 2014-06-03  1.021347       NaN
# 2014-06-04  1.019470       NaN
# 2014-06-05  1.023611  1.013285
# 2014-06-06  1.025512  1.021679
# 2014-06-09  1.020372  1.027470
# 2014-06-10  1.024868  1.026714

# %% [markdown]
# Plotting Algo Cumulative Returns

# %%
algo_cumulative_returns.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Daily Standard Deviation

# %%
algo_std = algo_returns_data.std()
algo_std
# Out:
# Algo 1    0.007972
# Algo 2    0.008466
# dtype: float64

# %% [markdown]
# Annual Standard Deviation

# %%
algo_annualized = algo_std * np.sqrt(252)
algo_annualized
# Out:
# Algo 1    0.126558
# Algo 2    0.134401
# dtype: float64

# %% [markdown]
# Algo Rolling Statistics

# %%
algo_returns_data.rolling(window=21).mean().tail(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2019-04-17  0.000475  0.000389
# 2019-04-18  0.000883  0.000283
# 2019-04-22  0.000914 -0.000034
# 2019-04-23  0.001031  0.001422
# 2019-04-24  0.001036  0.001539
# 2019-04-25  0.000809  0.000926
# 2019-04-26  0.000551  0.001389
# 2019-04-29  0.000326  0.001248
# 2019-04-30  0.000228  0.000956
# 2019-05-01 -0.000156  0.000260

# %% [markdown]
# Algo Rolling Stat Plot

# %%
algo_returns_data.rolling(window=21).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Plot Returns

# %%
SP_daily_returns.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# SP Cumulative Returns

# %%
SP_cumulative_returns = (1 + SP_daily_returns).cumprod()
SP_cumulative_returns.head(10)
# Out:
#            SP500 Returns
# Date
# 2019-04-23             1
# 2019-04-22      0.991236
# 2019-04-18      0.990234
# 2019-04-17      0.988673
# 2019-04-16      0.990926
# 2019-04-15      0.990422
# 2019-04-12      0.991045
# 2019-04-11      0.984538
# 2019-04-10      0.984501
# 2019-04-09      0.981089

# %% [markdown]
# Plotting SP Cumulative Returns

# %%
SP_cumulative_returns.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Daily Standard Deviation

# %%
SP_std = SP_daily_returns.std()
SP_std
# Out:
# SP500 Returns    0.008132
# dtype: float64

# %% [markdown]
# Annual Standard Deviation

# %%
SP_annualized = SP_std * np.sqrt(252)
SP_annualized
# Out:
# SP500 Returns    0.129094
# dtype: float64

# %% [markdown]
# SP Rolling Statistics

# %%
SP_daily_returns.rolling(window=21).mean().tail(10)
# Out:
#             SP500 Returns
# Date
# 2012-10-12       0.002547
# 2012-10-11       0.002020
# 2012-10-10       0.001820
# 2012-10-09       0.002123
# 2012-10-08       0.002679
# 2012-10-05       0.002256
# 2012-10-04       0.001115
# 2012-10-03       0.001147
# 2012-10-02       0.001078
# 2012-10-01       0.000585

# %% [markdown]
# SP Rolling Stat Plot

# %%
SP_daily_returns.rolling(window=21).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Calculated Correlation

# %%
correlation = joined_closing_data.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.700181
# PAULSON & CO.INC.                             0.700181            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561745            0.435333
# BERKSHIRE HATHAWAY INC                        0.754308            0.545802
# Algo 1                                        0.321366            0.269257
# Algo 2                                        0.826719            0.677993
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561745
# PAULSON & CO.INC.                               0.435333
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.425102
# Algo 1                                          0.164840
# Algo 2                                          0.508139
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2
# SOROS FUND MANAGEMENT LLC                  0.754308  0.321366  0.826719
# PAULSON & CO.INC.                          0.545802  0.269257  0.677993
# TIGER GLOBAL MANAGEMENT LLC                0.425102  0.164840  0.508139
# BERKSHIRE HATHAWAY INC                     1.000000  0.292307  0.687717
# Algo 1                                     0.292307  1.000000  0.346568
# Algo 2                                     0.687717  0.346568  1.000000

# %% [markdown]
# Plot Correlation

# %%
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Whale/SP Covariance

# %%
whale_sp_combined_cov = pd.concat([whale_cumulative_returns, SP_cumulative_returns], axis="columns", join="outer")
whale_sp_combined_cov
# Out:
#                      SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2012-10-01 00:00:00                        NaN                 NaN
# 2012-10-02 00:00:00                        NaN                 NaN
# 2012-10-03 00:00:00                        NaN                 NaN
# 2012-10-04 00:00:00                        NaN                 NaN
# 2012-10-05 00:00:00                        NaN                 NaN
# ...                                        ...                 ...
# 2019-04-25                            1.166895            0.779425
# 2019-04-26                            1.176404            0.786566
# 2019-04-29                            1.177880            0.788705
# 2019-04-30                            1.176355            0.786961
# 2019-05-01                            1.169477            0.785905
#
#                      TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  \
# Date
# 2012-10-01 00:00:00                          NaN                     NaN
# 2012-10-02 00:00:00                          NaN                     NaN
# 2012-10-03 00:00:00                          NaN                     NaN
# 2012-10-04 00:00:00                          NaN                     NaN
# 2012-10-05 00:00:00                          NaN                     NaN
# ...                                          ...                     ...
# 2019-04-25                              0.853324                1.550964
# 2019-04-26                              0.863867                1.567147
# 2019-04-29                              0.869267                1.575332
# 2019-04-30                              0.869041                1.569500
# 2019-05-01                              0.862145                1.557207
#
#                     SP500 Returns
# Date
# 2012-10-01 00:00:00      0.492382
# 2012-10-02 00:00:00      0.492811
# 2012-10-03 00:00:00      0.494597
# 2012-10-04 00:00:00      0.498146
# 2012-10-05 00:00:00      0.497985
# ...                           ...
# 2019-04-25                    NaN
# 2019-04-26                    NaN
# 2019-04-29                    NaN
# 2019-04-30                    NaN
# 2019-05-01                    NaN
#
# [2709 rows x 5 columns]

# %%
cov_daily_returns = whale_sp_combined_cov.pct_change()
cov_daily_returns
# Out:
#                      SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2012-10-01 00:00:00                        NaN                 NaN
# 2012-10-02 00:00:00                        NaN                 NaN
# 2012-10-03 00:00:00                        NaN                 NaN
# 2012-10-04 00:00:00                        NaN                 NaN
# 2012-10-05 00:00:00                        NaN                 NaN
# ...                                        ...                 ...
# 2019-04-25                           -0.000285           -0.001291
# 2019-04-26                            0.008149            0.009162
# 2019-04-29                            0.001254            0.002719
# 2019-04-30                           -0.001295           -0.002211
# 2019-05-01                           -0.005847           -0.001341
#
#                      TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  \
# Date
# 2012-10-01 00:00:00                          NaN                     NaN
# 2012-10-02 00:00:00                          NaN                     NaN
# 2012-10-03 00:00:00                          NaN                     NaN
# 2012-10-04 00:00:00                          NaN                     NaN
# 2012-10-05 00:00:00                          NaN                     NaN
# ...                                          ...                     ...
# 2019-04-25                             -0.005153                0.004848
# 2019-04-26                              0.012355                0.010434
# 2019-04-29                              0.006251                0.005223
# 2019-04-30                             -0.000259               -0.003702
# 2019-05-01                             -0.007936               -0.007833
#
#                      SP500 Returns
# Date
# 2012-10-01 00:00:00            NaN
# 2012-10-02 00:00:00       0.000872
# 2012-10-03 00:00:00       0.003624
# 2012-10-04 00:00:00       0.007174
# 2012-10-05 00:00:00      -0.000322
# ...                            ...
# 2019-04-25                0.000000
# 2019-04-26                0.000000
# 2019-04-29                0.000000
# 2019-04-30                0.000000
# 2019-05-01                0.000000
#
# [2709 rows x 5 columns]

# %%
covariance = cov_daily_returns['SOROS FUND MANAGEMENT LLC'].cov(cov_daily_returns['SP500 Returns'])
covariance
# Out:
# 0.0

# %% [markdown]
# Variance of SP 500

# %%
variance = joined_closing_data['SP500 Returns'].var()
variance
# Out:
# 6.613235285531793e-05

# %% [markdown]
# Plot Beta Trend

# %% [markdown]
# Sharpe Ratios

# %%
sharpe_ratios = ((joined_closing_data.mean()-joined_closing_data.mean()) * 252) / (joined_closing_data.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.0
# PAULSON & CO.INC.              0.0
# TIGER GLOBAL MANAGEMENT LLC    0.0
# BERKSHIRE HATHAWAY INC         0.0
# Algo 1                         0.0
# Algo 2                         0.0
# SP500 Returns                  0.0
# dtype: float64

# %%
AAPL_365 = pd.read_csv("APPLE_365.csv")
COSTCO_365 = pd.read_csv("COSTCO_365.csv")
GOOGLE_365 = pd.read_csv("GOOGLE_365.csv")

# %% [markdown]
# Data from Apple

# %%
AAPL_365.head(10)
# Out:
#                 Apple Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                AAPL        NaN        NaN        NaN        NaN        NaN
# 1                Date       Open       High        Low      Close     Volume
# 2  3/26/2020 16:00:00      61.63      64.67      61.59      64.61   63140169
# 3  3/27/2020 16:00:00      63.19      63.97      61.76      61.94   51054153
# 4  3/30/2020 16:00:00      62.69      63.88      62.35       63.7   41994110
# 5  3/31/2020 16:00:00       63.9      65.62         63      63.57   49250501
# 6   4/1/2020 16:00:00      61.63      62.18      59.78      60.23   44054638
# 7   4/2/2020 16:00:00      60.09      61.29      59.23      61.23   41483493
# 8   4/3/2020 16:00:00       60.7      61.43      59.74      60.35   32470017
# 9   4/6/2020 16:00:00      62.73      65.78      62.35      65.62   50455071

# %%
AAPL_365.isnull().sum()
# Out:
# Apple         0
# Unnamed: 1    1
# Unnamed: 2    1
# Unnamed: 3    1
# Unnamed: 4    1
# Unnamed: 5    1
# dtype: int64

# %%
AAPL_365 = AAPL_365.fillna("Unknown")
AAPL_365
# Out:
#                   Apple Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                  AAPL    Unknown    Unknown    Unknown    Unknown    Unknown
# 1                  Date       Open       High        Low      Close     Volume
# 2    3/26/2020 16:00:00      61.63      64.67      61.59      64.61   63140169
# 3    3/27/2020 16:00:00      63.19      63.97      61.76      61.94   51054153
# 4    3/30/2020 16:00:00      62.69      63.88      62.35       63.7   41994110
# ..                  ...        ...        ...        ...        ...        ...
# 249  3/19/2021 16:00:00      119.9     121.43     119.68     119.99  185549522
# 250  3/22/2021 16:00:00     120.33     123.87     120.26     123.39  111912284
# 251  3/23/2021 16:00:00     123.33     124.24     122.14     122.54   95467142
# 252  3/24/2021 16:00:00     122.82      122.9     120.07     120.09   88530485
# 253  3/25/2021 16:00:00     119.54     121.66        119     120.59   98844681
#
# [254 rows x 6 columns]

# %%
AAPL_365 = AAPL_365.dropna()
AAPL_365
# Out:
#                   Apple Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                  AAPL    Unknown    Unknown    Unknown    Unknown    Unknown
# 1                  Date       Open       High        Low      Close     Volume
# 2    3/26/2020 16:00:00      61.63      64.67      61.59      64.61   63140169
# 3    3/27/2020 16:00:00      63.19      63.97      61.76      61.94   51054153
# 4    3/30/2020 16:00:00      62.69      63.88      62.35       63.7   41994110
# ..                  ...        ...        ...        ...        ...        ...
# 249  3/19/2021 16:00:00      119.9     121.43     119.68     119.99  185549522
# 250  3/22/2021 16:00:00     120.33     123.87     120.26     123.39  111912284
# 251  3/23/2021 16:00:00     123.33     124.24     122.14     122.54   95467142
# 252  3/24/2021 16:00:00     122.82      122.9     120.07     120.09   88530485
# 253  3/25/2021 16:00:00     119.54     121.66        119     120.59   98844681
#
# [254 rows x 6 columns]

# %%
AAPL_365.isnull().sum()
# Out:
# Apple         0
# Unnamed: 1    0
# Unnamed: 2    0
# Unnamed: 3    0
# Unnamed: 4    0
# Unnamed: 5    0
# dtype: int64

# %%
AAPL_365 = AAPL_365.drop(columns = ['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5'])
AAPL_365
# Out:
#                   Apple Unnamed: 4
# 0                  AAPL    Unknown
# 1                  Date      Close
# 2    3/26/2020 16:00:00      64.61
# 3    3/27/2020 16:00:00      61.94
# 4    3/30/2020 16:00:00       63.7
# ..                  ...        ...
# 249  3/19/2021 16:00:00     119.99
# 250  3/22/2021 16:00:00     123.39
# 251  3/23/2021 16:00:00     122.54
# 252  3/24/2021 16:00:00     120.09
# 253  3/25/2021 16:00:00     120.59
#
# [254 rows x 2 columns]

# %%
AAPL_365 = AAPL_365.rename(columns={
    "Apple": "Date"
})
AAPL_365
# Out:
#                    Date Unnamed: 4
# 0                  AAPL    Unknown
# 1                  Date      Close
# 2    3/26/2020 16:00:00      64.61
# 3    3/27/2020 16:00:00      61.94
# 4    3/30/2020 16:00:00       63.7
# ..                  ...        ...
# 249  3/19/2021 16:00:00     119.99
# 250  3/22/2021 16:00:00     123.39
# 251  3/23/2021 16:00:00     122.54
# 252  3/24/2021 16:00:00     120.09
# 253  3/25/2021 16:00:00     120.59
#
# [254 rows x 2 columns]

# %%
AAPL_365 = AAPL_365.drop([0,1])

# %%
AAPL_365.set_index(pd.to_datetime(AAPL_365['Date'], infer_datetime_format=True), inplace=True)
AAPL_365
# Out:
#                                    Date Unnamed: 4
# Date
# 2020-03-26 16:00:00  3/26/2020 16:00:00      64.61
# 2020-03-27 16:00:00  3/27/2020 16:00:00      61.94
# 2020-03-30 16:00:00  3/30/2020 16:00:00       63.7
# 2020-03-31 16:00:00  3/31/2020 16:00:00      63.57
# 2020-04-01 16:00:00   4/1/2020 16:00:00      60.23
# ...                                 ...        ...
# 2021-03-19 16:00:00  3/19/2021 16:00:00     119.99
# 2021-03-22 16:00:00  3/22/2021 16:00:00     123.39
# 2021-03-23 16:00:00  3/23/2021 16:00:00     122.54
# 2021-03-24 16:00:00  3/24/2021 16:00:00     120.09
# 2021-03-25 16:00:00  3/25/2021 16:00:00     120.59
#
# [252 rows x 2 columns]

# %%
AAPL_365 = AAPL_365.drop(columns=["Date"])
AAPL_365
# Out:
#                     Unnamed: 4
# Date
# 2020-03-26 16:00:00      64.61
# 2020-03-27 16:00:00      61.94
# 2020-03-30 16:00:00       63.7
# 2020-03-31 16:00:00      63.57
# 2020-04-01 16:00:00      60.23
# ...                        ...
# 2021-03-19 16:00:00     119.99
# 2021-03-22 16:00:00     123.39
# 2021-03-23 16:00:00     122.54
# 2021-03-24 16:00:00     120.09
# 2021-03-25 16:00:00     120.59
#
# [252 rows x 1 columns]

# %%
AAPL_365 = AAPL_365.rename(columns={
   "Unnamed: 4": "Apple"
})
AAPL_365
# Out:
#                       Apple
# Date
# 2020-03-26 16:00:00   64.61
# 2020-03-27 16:00:00   61.94
# 2020-03-30 16:00:00    63.7
# 2020-03-31 16:00:00   63.57
# 2020-04-01 16:00:00   60.23
# ...                     ...
# 2021-03-19 16:00:00  119.99
# 2021-03-22 16:00:00  123.39
# 2021-03-23 16:00:00  122.54
# 2021-03-24 16:00:00  120.09
# 2021-03-25 16:00:00  120.59
#
# [252 rows x 1 columns]

# %%
AAPL_365.index = AAPL_365.index.normalize()
AAPL_365
# Out:
#              Apple
# Date
# 2020-03-26   64.61
# 2020-03-27   61.94
# 2020-03-30    63.7
# 2020-03-31   63.57
# 2020-04-01   60.23
# ...            ...
# 2021-03-19  119.99
# 2021-03-22  123.39
# 2021-03-23  122.54
# 2021-03-24  120.09
# 2021-03-25  120.59
#
# [252 rows x 1 columns]

# %% [markdown]
# Data from Costco

# %%
COSTCO_365.head(10)
# Out:
#                Costco Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                COST        NaN        NaN        NaN        NaN        NaN
# 1                Date       Open       High        Low      Close     Volume
# 2  3/26/2020 16:00:00     281.34     293.73     280.86      292.3    5471961
# 3  3/27/2020 16:00:00     287.13     293.49     283.33     284.33    4250350
# 4  3/30/2020 16:00:00     287.49     291.68     285.84     291.12    4395977
# 5  3/31/2020 16:00:00     287.42     291.52        284     285.13    5623886
# 6   4/1/2020 16:00:00     282.36      288.8      280.9     286.78    3745783
# 7   4/2/2020 16:00:00     284.38     292.78     282.82     291.48    3500595
# 8   4/3/2020 16:00:00     289.16     292.34      285.8     288.65    2650063
# 9   4/6/2020 16:00:00        293     305.49     289.57     305.12    5272534

# %%
COSTCO_365.isnull().sum()
# Out:
# Costco        0
# Unnamed: 1    1
# Unnamed: 2    1
# Unnamed: 3    1
# Unnamed: 4    1
# Unnamed: 5    1
# dtype: int64

# %%
COSTCO_365 = COSTCO_365.fillna("Unknown")

# %%
COSTCO_365.dropna()
# Out:
#                  Costco Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                  COST    Unknown    Unknown    Unknown    Unknown    Unknown
# 1                  Date       Open       High        Low      Close     Volume
# 2    3/26/2020 16:00:00     281.34     293.73     280.86      292.3    5471961
# 3    3/27/2020 16:00:00     287.13     293.49     283.33     284.33    4250350
# 4    3/30/2020 16:00:00     287.49     291.68     285.84     291.12    4395977
# ..                  ...        ...        ...        ...        ...        ...
# 249  3/19/2021 16:00:00     323.61     329.25     322.39     328.91    4859256
# 250  3/22/2021 16:00:00     328.45     336.17     328.19     334.49    4064876
# 251  3/23/2021 16:00:00     333.89     342.51      333.8     340.34    3641218
# 252  3/24/2021 16:00:00     342.22     342.51     336.83     338.04    3006369
# 253  3/25/2021 16:00:00     337.81     347.78     337.27     346.34    4307145
#
# [254 rows x 6 columns]

# %%
COSTCO_365.isnull().sum()
# Out:
# Costco        0
# Unnamed: 1    0
# Unnamed: 2    0
# Unnamed: 3    0
# Unnamed: 4    0
# Unnamed: 5    0
# dtype: int64

# %%
COSTCO_365 = COSTCO_365.drop(columns = ['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5'])

# %%
COSTCO_365 = COSTCO_365.rename(columns={
    "Costco": "Date"
})
COSTCO_365
# Out:
#                    Date Unnamed: 4
# 0                  COST    Unknown
# 1                  Date      Close
# 2    3/26/2020 16:00:00      292.3
# 3    3/27/2020 16:00:00     284.33
# 4    3/30/2020 16:00:00     291.12
# ..                  ...        ...
# 249  3/19/2021 16:00:00     328.91
# 250  3/22/2021 16:00:00     334.49
# 251  3/23/2021 16:00:00     340.34
# 252  3/24/2021 16:00:00     338.04
# 253  3/25/2021 16:00:00     346.34
#
# [254 rows x 2 columns]

# %%
COSTCO_365 = COSTCO_365.drop([0,1])

# %%
COSTCO_365.set_index(pd.to_datetime(COSTCO_365['Date'], infer_datetime_format=True), inplace=True)

# %%
COSTCO_365 = COSTCO_365.drop(columns=["Date"])

# %%
COSTCO_365 = COSTCO_365.rename(columns={
   "Unnamed: 4": "COSTCO"
})
COSTCO_365
# Out:
#                      COSTCO
# Date
# 2020-03-26 16:00:00   292.3
# 2020-03-27 16:00:00  284.33
# 2020-03-30 16:00:00  291.12
# 2020-03-31 16:00:00  285.13
# 2020-04-01 16:00:00  286.78
# ...                     ...
# 2021-03-19 16:00:00  328.91
# 2021-03-22 16:00:00  334.49
# 2021-03-23 16:00:00  340.34
# 2021-03-24 16:00:00  338.04
# 2021-03-25 16:00:00  346.34
#
# [252 rows x 1 columns]

# %%
COSTCO_365.index = COSTCO_365.index.normalize()
COSTCO_365
# Out:
#             COSTCO
# Date
# 2020-03-26   292.3
# 2020-03-27  284.33
# 2020-03-30  291.12
# 2020-03-31  285.13
# 2020-04-01  286.78
# ...            ...
# 2021-03-19  328.91
# 2021-03-22  334.49
# 2021-03-23  340.34
# 2021-03-24  338.04
# 2021-03-25  346.34
#
# [252 rows x 1 columns]

# %% [markdown]
# Data from Google

# %%
GOOGLE_365.head(10)
# Out:
#                Google Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                GOOG        NaN        NaN        NaN        NaN        NaN
# 1                Date       Open       High        Low      Close     Volume
# 2  3/26/2020 16:00:00     1111.8    1169.97    1093.53    1161.75    3573755
# 3  3/27/2020 16:00:00    1125.67    1150.67    1105.91    1110.71    3208495
# 4  3/30/2020 16:00:00    1125.04    1151.63    1096.48    1146.82    2574061
# 5  3/31/2020 16:00:00     1147.3    1175.31    1138.14    1162.81    2487983
# 6   4/1/2020 16:00:00       1122    1129.69    1097.45    1105.62    2344173
# 7   4/2/2020 16:00:00    1098.26    1126.86     1096.4    1120.84    1964881
# 8   4/3/2020 16:00:00    1119.02    1123.54    1079.81    1097.88    2313400
# 9   4/6/2020 16:00:00       1138    1194.66    1130.94    1186.92    2664723

# %%
GOOGLE_365.isnull().sum()
# Out:
# Google        0
# Unnamed: 1    1
# Unnamed: 2    1
# Unnamed: 3    1
# Unnamed: 4    1
# Unnamed: 5    1
# dtype: int64

# %%
GOOGLE_365 = GOOGLE_365.fillna("Unknown")

# %%
GOOGLE_365.dropna()
# Out:
#                  Google Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                  GOOG    Unknown    Unknown    Unknown    Unknown    Unknown
# 1                  Date       Open       High        Low      Close     Volume
# 2    3/26/2020 16:00:00     1111.8    1169.97    1093.53    1161.75    3573755
# 3    3/27/2020 16:00:00    1125.67    1150.67    1105.91    1110.71    3208495
# 4    3/30/2020 16:00:00    1125.04    1151.63    1096.48    1146.82    2574061
# ..                  ...        ...        ...        ...        ...        ...
# 249  3/19/2021 16:00:00    2042.05     2053.1    2017.68     2043.2    2314893
# 250  3/22/2021 16:00:00    2041.84    2057.99    2026.07    2038.59    1954816
# 251  3/23/2021 16:00:00     2051.7     2072.3    2039.22    2052.96    1366997
# 252  3/24/2021 16:00:00    2065.37    2078.21    2041.56    2045.06    1154029
# 253  3/25/2021 16:00:00    2044.81    2058.87    2010.73    2044.36    1418907
#
# [254 rows x 6 columns]

# %%
GOOGLE_365.isnull().sum()
# Out:
# Google        0
# Unnamed: 1    0
# Unnamed: 2    0
# Unnamed: 3    0
# Unnamed: 4    0
# Unnamed: 5    0
# dtype: int64

# %%
GOOGLE_365 = GOOGLE_365.drop(columns = ['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5'])

# %%
GOOGLE_365 = GOOGLE_365.rename(columns = {
    "Google": "Date"
})
GOOGLE_365
# Out:
#                    Date Unnamed: 4
# 0                  GOOG    Unknown
# 1                  Date      Close
# 2    3/26/2020 16:00:00    1161.75
# 3    3/27/2020 16:00:00    1110.71
# 4    3/30/2020 16:00:00    1146.82
# ..                  ...        ...
# 249  3/19/2021 16:00:00     2043.2
# 250  3/22/2021 16:00:00    2038.59
# 251  3/23/2021 16:00:00    2052.96
# 252  3/24/2021 16:00:00    2045.06
# 253  3/25/2021 16:00:00    2044.36
#
# [254 rows x 2 columns]

# %%
GOOGLE_365 = GOOGLE_365.drop([0,1])

# %%
GOOGLE_365.set_index(pd.to_datetime(GOOGLE_365['Date'], infer_datetime_format=True), inplace=True)

# %%
GOOGLE_365 = GOOGLE_365.drop(columns=["Date"])

# %%
GOOGLE_365 = GOOGLE_365.rename(columns={
   "Unnamed: 4": "GOOGLE"
})
GOOGLE_365
# Out:
#                       GOOGLE
# Date
# 2020-03-26 16:00:00  1161.75
# 2020-03-27 16:00:00  1110.71
# 2020-03-30 16:00:00  1146.82
# 2020-03-31 16:00:00  1162.81
# 2020-04-01 16:00:00  1105.62
# ...                      ...
# 2021-03-19 16:00:00   2043.2
# 2021-03-22 16:00:00  2038.59
# 2021-03-23 16:00:00  2052.96
# 2021-03-24 16:00:00  2045.06
# 2021-03-25 16:00:00  2044.36
#
# [252 rows x 1 columns]

# %%
GOOGLE_365.index = GOOGLE_365.index.normalize()
GOOGLE_365
# Out:
#              GOOGLE
# Date
# 2020-03-26  1161.75
# 2020-03-27  1110.71
# 2020-03-30  1146.82
# 2020-03-31  1162.81
# 2020-04-01  1105.62
# ...             ...
# 2021-03-19   2043.2
# 2021-03-22  2038.59
# 2021-03-23  2052.96
# 2021-03-24  2045.06
# 2021-03-25  2044.36
#
# [252 rows x 1 columns]

# %% [markdown]
# Preparing to Concatenate

# %%
joined_data = pd.concat([AAPL_365, COSTCO_365, GOOGLE_365], axis="columns", join="outer")
joined_data
# Out:
#              Apple  COSTCO   GOOGLE
# Date
# 2020-03-26   64.61   292.3  1161.75
# 2020-03-27   61.94  284.33  1110.71
# 2020-03-30    63.7  291.12  1146.82
# 2020-03-31   63.57  285.13  1162.81
# 2020-04-01   60.23  286.78  1105.62
# ...            ...     ...      ...
# 2021-03-19  119.99  328.91   2043.2
# 2021-03-22  123.39  334.49  2038.59
# 2021-03-23  122.54  340.34  2052.96
# 2021-03-24  120.09  338.04  2045.06
# 2021-03-25  120.59  346.34  2044.36
#
# [252 rows x 3 columns]

# %%
joined_data.isnull().sum()
# Out:
# Apple     0
# COSTCO    0
# GOOGLE    0
# dtype: int64

# %%
joined_data = joined_data.astype(float)

# %%
joined_data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
daily_returns = joined_data.pct_change()
daily_returns
# Out:
#                Apple    COSTCO    GOOGLE
# Date
# 2020-03-26       NaN       NaN       NaN
# 2020-03-27 -0.041325 -0.027267 -0.043934
# 2020-03-30  0.028415  0.023881  0.032511
# 2020-03-31 -0.002041 -0.020576  0.013943
# 2020-04-01 -0.052541  0.005787 -0.049183
# ...              ...       ...       ...
# 2021-03-19 -0.004480  0.018360  0.003428
# 2021-03-22  0.028336  0.016965 -0.002256
# 2021-03-23 -0.006889  0.017489  0.007049
# 2021-03-24 -0.019993 -0.006758 -0.003848
# 2021-03-25  0.004164  0.024553 -0.000342
#
# [252 rows x 3 columns]

# %%
daily_returns = daily_returns.dropna()
daily_returns
# Out:
#                Apple    COSTCO    GOOGLE
# Date
# 2020-03-27 -0.041325 -0.027267 -0.043934
# 2020-03-30  0.028415  0.023881  0.032511
# 2020-03-31 -0.002041 -0.020576  0.013943
# 2020-04-01 -0.052541  0.005787 -0.049183
# 2020-04-02  0.016603  0.016389  0.013766
# ...              ...       ...       ...
# 2021-03-19 -0.004480  0.018360  0.003428
# 2021-03-22  0.028336  0.016965 -0.002256
# 2021-03-23 -0.006889  0.017489  0.007049
# 2021-03-24 -0.019993 -0.006758 -0.003848
# 2021-03-25  0.004164  0.024553 -0.000342
#
# [251 rows x 3 columns]

# %% [markdown]
# Weighted Returns

# %%
Apple_weight = 0.33
COSTCO_weight = 0.33
GOOGLE_weight = 0.33

portfolio_returns = Apple_weight * daily_returns["Apple"] + COSTCO_weight * daily_returns["COSTCO"] + GOOGLE_weight * daily_returns["GOOGLE"]
portfolio_returns.head()
# Out:
# Date
# 2020-03-27   -0.037133
# 2020-03-30    0.027986
# 2020-03-31   -0.002862
# 2020-04-01   -0.031659
# 2020-04-02    0.015430
# dtype: float64

# %%
joined_HW_data = pd.concat([daily_returns, joined_closing_data], axis="columns", join="inner")
joined_HW_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2012-10-01                        NaN                 NaN
# 2012-10-02                        NaN                 NaN
# 2012-10-03                        NaN                 NaN
# 2012-10-04                        NaN                 NaN
# 2012-10-05                        NaN                 NaN
# ...                               ...                 ...
# 2019-04-16                  -2.898341           -1.335693
# 2019-04-17                  -2.073108          -17.661104
# 2019-04-18                  -1.499843           -1.188925
# 2019-04-22                  -2.785826           -7.001458
# 2019-04-23                  -3.771893           -1.475216
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC SP500 Returns  \
# Date
# 2012-10-01                          NaN                     NaN           NaN
# 2012-10-02                          NaN                     NaN      0.000872
# 2012-10-03                          NaN                     NaN      0.003624
# 2012-10-04                          NaN                     NaN      0.007174
# 2012-10-05                          NaN                     NaN     -0.000322
# ...                                 ...                     ...           ...
# 2019-04-16                    -3.088322               -1.079744      0.000509
# 2019-04-17                     4.306537                2.851033     -0.002274
# 2019-04-18                    -1.131886               -0.405345      0.001579
# 2019-04-22                    -7.259521               -1.567709      0.001012
# 2019-04-23                    -2.777848              -13.206260      0.008841
#
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2012-10-01                        NaN                 NaN
# 2012-10-02                        NaN                 NaN
# 2012-10-03                        NaN                 NaN
# 2012-10-04                        NaN                 NaN
# 2012-10-05                        NaN                 NaN
# ...                               ...                 ...
# 2019-04-16                        NaN                 NaN
# 2019-04-17                        NaN                 NaN
# 2019-04-18                        NaN                 NaN
# 2019-04-22                        NaN                 NaN
# 2019-04-23                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2012-10-01                          NaN                     NaN     NaN
# 2012-10-02                          NaN                     NaN     NaN
# 2012-10-03                          NaN                     NaN     NaN
# 2012-10-04                          NaN                     NaN     NaN
# 2012-10-05                          NaN                     NaN     NaN
# ...                                 ...                     ...     ...
# 2019-04-16                          NaN                     NaN     NaN
# 2019-04-17                          NaN                     NaN     NaN
# 2019-04-18                          NaN                     NaN     NaN
# 2019-04-22                          NaN                     NaN     NaN
# 2019-04-23                          NaN                     NaN     NaN
#
#             Algo 2 SP500 Returns
# Date
# 2012-10-01     NaN   -0.00087152
# 2012-10-02     NaN   -0.00361133
# 2012-10-03     NaN   -0.00712331
# 2012-10-04     NaN   0.000321713
# 2012-10-05     NaN    0.00346869
# ...            ...           ...
# 2019-04-16     NaN    0.00227896
# 2019-04-17     NaN   -0.00157658
# 2019-04-18     NaN   -0.00101101
# 2019-04-22     NaN   -0.00876374
# 2019-04-23     NaN             0
#
# [1649 rows x 12 columns]
